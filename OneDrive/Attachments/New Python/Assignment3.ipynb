# %%
movies=[]
movies.append(input("Enter your first movie:"))
movies.append(input("Enter your second movie:"))
movies.append(input("Enter your third movie:"))
print("Your Movies list :",movies)
# Out:
# Your Movies list : ['ibnu', 'raka', 'thauu']

# %%
Sales= (1200, 1500, 900, 1700, 1100,2000, 1800)
print(max(Sales))
print(min(Sales))
# Out:
# 2000
# 900

# %%
List= ["Milk", "Bread", "Eggs"]
print(List.insert(3,"Butter"))
print(List)
# Out:
# None
# ['Milk', 'Bread', 'Eggs', 'Butter']

# %%
Marks=[56, 78, 45, 90, 67]
print(sum(Marks))
average=336/5
print(average)
# Out:
# 336
# 67.2

# %%
a=["Song A", "Song B", "Song C", "Song D"]
print(a.remove("Song C"))
print(a)
# Out:
# None
# ['Song A', 'Song B', 'Song D']

# %%
Ages=[15, 22, 34, 45, 19]
print(Ages.sort())
print(Ages)
# Out:
# None
# [15, 19, 22, 34, 45]

# %%
Team=["Rahul", "Aman", "Vikram", "Sunil", "Ravi"]
Team[2]="Kiran"
print(Team)
# Out:
# ['Rahul', 'Aman', 'Kiran', 'Sunil', 'Ravi']

# %%
contacts1 = [9998887771,9998887772]
contacts2 = [9998887773, 9998887774]
print(contacts1+contacts2)
# Out:
# [9998887771, 9998887772, 9998887773, 9998887774]

# %%
Score=[88, 45, 67, 45, 92, 45]
print(Score.count(45))
# Out:
# 3

# %%
Rating=[4.5, 3.8, 4.9, 4.1, 3.5]
print(max(Rating))
# Out:
# 4.9

# %%
a=[input("enters 1 product price")]
b=[input("enters 2 product price")]
c=[input("enters 3 product price")]
d=[input("enters 4 product price")]
e=[input("enters 5 product price")]
print(a+b+c+d+e)
# Out:
# ['45', '62', '68', '34', '45']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 8
#       4 d=[input("enters 4 product price")]
#       5 e=[input("enters 5 product price")]
#       6 print(a+b+c+d+e)
#       7 total=(a+b+c+d+e)
# ----> 8 print(sum(total))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
List= ["admin", "guest123", "root", "test_user"]
print(List.index("root"))
# Out:
# 2
