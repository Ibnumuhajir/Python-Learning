# %%
Text="Programming"
print(Text[::2])
# Out:
# Pormig

# %%
Text= "python"
print("thon" in Text)
# Out:
# True

# %%
Text=['Python', 'Java', 'SQL']
print("-".join(Text))
# Out:
# Python-Java-SQL

# %%
Text="Python,Java,SQL"
print(Text.split(","))
# Out:
# ['Python', 'Java', 'SQL']

# %%
Text= "IBNU"
print(Text.lower())
# Out:
# ibnu

# %%
Text= "Ibnu"
print(Text.upper())
# Out:
# IBNU

# %%
Text= "Java is simple & powerful"
print(Text.replace("Java","Python"))
# Out:
# Python is simple & powerful

# %%
Text="banana"
print(Text.count("a"))
# Out:
# 3

# %%
Name = "Ibnu"
print(Name[ : :-1])
# Out:
# unbI

# %%
Name = "Ibnu"
print(Name[3])
# Out:
# u

# %% [markdown]
# Name = "Ibnu"
# print(Name[3])

# %%
Name="Ibnu"
print(Name[0])
# Out:
# I

# %%
a=(input("Enter First Name:"))
b=(input("Enter second name:"))
c=int(input("Enter birth Year:"))
d=str(input("Enter Place:"))
e=float(input("Your Weight:"))
f=float(input("Your Height"))
g=int(input("Enter your mobile Number:"))
h=str(input("Enter mail id:"))
print(f"your Name is {a + b}")
Year = 2026
print(f"your Age is: {Year-c}")
print(f"you are From: {d}")
print(f"your Weight:{e}")
print(f"Your Height:{f}")
print(f"Phone Number: {g}")
print(f"Your Mail: {h}")
# Out:
# your Name is ibnumuhajir
# your Age is: 22
# you are From: tirur
# your Weight:65.0
# Your Height:6.5
# Phone Number: 9645506865
# Your Mail: ibnumuhajir@gmail.com
