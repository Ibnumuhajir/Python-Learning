# %%
a="ibnu muhjair"
print(a.upper())
# Out:
# IBNU MUHJAIR

# %%
a="student@gmail.com"
print(len(a))
# Out:
# 17

# %%
Customer= " Amazing product, highly recommend! "
print(Customer.strip())
# Out:
# Amazing product, highly recommend!

# %%
User= str(input("enter a book title in lowercase:"))
print(User.title())
# Out:
# The Goatlife

# %%
Slogan= "We build apps for Java developers"
print(Slogan.replace("Java","Python"))
# Out:
# We build apps for Python developers

# %%
a= input("enter your full name: ")
print("your Username is: ",a[0:4:])
# Out:
# your Username is:  ibnu

# %%
Subject= "Maths,Science,English,History"
print(Subject.split(","))
# Out:
# ['Maths', 'Science', 'English', 'History']

# %%
User= input("Enter any sentance: ")
print("Total Number of words is:",len(User))
# Out:
# Total Number of words is: 11

# %%
Word= "level"
print(Word[::-1])
# Out:
# level

# %%
Word="banana"
print(Word.count("a"))
# Out:
# 3

# %%
User=input("Enter your user name:")
print(User.startswith("Admin"))
# Out:
# True

# %%
User= input("enters your date of birth as text in the format:")
print(User[6::])
# Out:
# 1903
